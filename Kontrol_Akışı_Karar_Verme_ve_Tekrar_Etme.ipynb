# %% [markdown]
# <a href="https://colab.research.google.com/github/imend35/verianalizokulu-yapayzeka-python/blob/main/Kontrol_Ak%C4%B1%C5%9F%C4%B1_Karar_Verme_ve_Tekrar_Etme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mükemmel\! Artık değişkenlerle nasıl çalışacağınızı ve onlarla nasıl işlem yapacağınızı biliyorsunuz. Şimdi, programlarımızın hayat bulduğu ve **karar verme yeteneği** kazandığı aşamaya, yani **Kontrol Akışı** konusuna geçiyoruz.
#
# Bu aşamada, kodunuzun hangi durumlarda hangi satırları çalıştırması gerektiğini belirleyeceksiniz.
#
# -----
#
# ## 4\. Kontrol Akışı: Karar Verme ve Tekrar Etme
#
# Kontrol Akışı, programlama mantığının merkezidir ve iki ana bileşenden oluşur:
#
# ### 4.1. Koşullu İfadeler (If, Elif, Else)
#
# Programınızın belirli koşullara göre farklı yollar izlemesini sağlar. Bir kapıdaki güvenlik sistemi gibi düşünebilirsiniz: Eğer şifre doğruysa kapı açılır, değilse alarm çalar.
#
# #### 💡 Söz Dizimi (Syntax)
#
# 1.  **`if`:** Ana koşulu kontrol eder. Eğer koşul doğruysa (`True`), altındaki girintili (indent) kod bloğu çalışır.
# 2.  **`elif` (Else If):** İlk koşul (`if`) yanlışsa, diğer olası koşulları kontrol eder. İstediğiniz kadar `elif` ekleyebilirsiniz.
# 3.  **`else`:** Yukarıdaki koşulların **hiçbiri** doğru değilse çalışacak varsayılan kod bloğudur.
#
# <!-- end list -->
#
# ```python
# hava_durumu = "yağmurlu"
#
# if hava_durumu == "güneşli":
#     print("Dışarı çıkıp spor yap.")
# elif hava_durumu == "yağmurlu":
#     print("Şemsiyeni al ve evde film izle.") # Bu blok çalışacak
# else:
#     print("Ne yapacağına karar veremedim.")
# ```
#
# > **Önemli: Girintiler (Indentation)**
# > Python'da, bir kod bloğunun (örneğin bir `if` bloğunun) nereye kadar sürdüğünü belirtmek için küme parantezleri (`{}`) yerine **girintiler (genellikle 4 boşluk)** kullanılır. Bu, Python'ı okunabilir kılan temel kuraldır.
#
# ### 4.2. Döngüler (Loops)
#
# Döngüler, aynı kod bloğunu art arda, belirli sayıda veya bir koşul doğru olduğu sürece tekrar çalıştırmamızı sağlar. Kod tekrarını önlerler.
#
# #### A) For Döngüsü (For Loop)
#
# Genellikle bir listedeki veya bir metindeki elemanların **her birini tek tek gezmek** için kullanılır.
#
# ```python
# # Bir listedeki tüm meyveleri tek tek yazdırma
# meyveler = ["elma", "muz", "çilek"]
#
# for meyve in meyveler:
#     print(f"Elimde bir {meyve} var.")
#     # f"..." kullanımı F-String olarak adlandırılır.
#     # Değişkenleri metin içine kolayca yerleştirmeyi sağlar.
# ```
#
# **`range()` Fonksiyonu:** Belirli sayıda tekrar yapmak istiyorsanız `range()` kullanırsınız. `range(5)` demek 0'dan başlayıp 4'e kadar (5 dahil değil) saymak demektir.
#
# ```python
# for i in range(3):
#     print(f"Tekrar Sayısı: {i}")
#     # Çıktı: 0, 1, 2
# ```
#
# #### B) While Döngüsü (While Loop)
#
# Bir koşul **`True` (Doğru)** olduğu sürece çalışmaya devam eder. Koşul **`False`** olduğunda döngü durur.
#
# ```python
# sayac = 0
#
# while sayac < 5:
#     print(f"Sayaç: {sayac}")
#     sayac += 1 # Dikkat! Bu satır olmazsa döngü sonsuza kadar çalışır!
#
# print("Döngü Bitti.")
# ```
#
# #### Döngü Kontrol Deyimleri: `break` ve `continue`
#
#   * **`break`:** Döngünün tamamını anında durdurur ve döngüden çıkar.
#   * **`continue`:** Mevcut iterasyonu atlar ve döngünün bir sonraki adımına geçer.
#
# <!-- end list -->
#
# ```python
# for i in range(10):
#     if i == 3:
#         continue # 3'ü yazdırmadan atla
#     if i == 7:
#         break    # 7'ye gelince döngüyü tamamen durdur
#     print(i) # Çıktı: 0, 1, 2, 4, 5, 6
# ```
#
# -----
#
# ## 📝 Alıştırma: Kontrol Akışı
#
# Şimdi, öğrendiğiniz `if-elif-else` ve döngüleri birleştiren bir uygulama yapın:
#
# 1.  `not_degeri` adında bir değişken tanımlayın ve bir sayı atayın (örn: 85).
# 2.  Aşağıdaki kurallara göre notu değerlendiren bir `if-elif-else` yapısı oluşturun:
#       * Eğer not 90 ve üzeriyse "A Aldınız, Tebrikler\!" yazdırın.
#       * Eğer not 80 ile 89 arasındaysa "B Aldınız." yazdırın.
#       * Diğer tüm durumlarda "Tekrar Deneyin." yazdırın.
# 3.  1'den 10'a kadar olan sayıları bir **For döngüsü** ile ekrana yazdırın, ancak `i` değişkeni 7 olduğunda `break` komutunu kullanarak döngüyü durdurun.
#
# Bu alıştırmalar, programlama mantığınızı geliştirecek. Bir sonraki aşamada **Veri Yapılarına (Listeler, Sözlükler)** geçeceğiz. **Hazır olduğunuzda bana bildirin\!**

# %%
hava_durumu = "yağmurlu"

if hava_durumu == "güneşli":
    print("Dışarı çıkıp spor yap.")
elif hava_durumu == "yağmurlu":
    print("Şemsiyeni al ve evde film izle.") # Bu blok çalışacak
else:
    print("Ne yapacağına karar veremedim.")

# %%
# Bir listedeki tüm meyveleri tek tek yazdırma
meyveler = ["elma", "muz", "çilek"]

for meyve in meyveler:
    print(f"Elimde bir {meyve} var.")
    # f"..." kullanımı F-String olarak adlandırılır.
    # Değişkenleri metin içine kolayca yerleştirmeyi sağlar.

# %%
for i in range(3):
    print(f"Tekrar Sayısı: {i}")
    # Çıktı: 0, 1, 2

# %%
sayac = 0

while sayac < 5:
    print(f"Sayaç: {sayac}")
    sayac += 1 # Dikkat! Bu satır olmazsa döngü sonsuza kadar çalışır!

print("Döngü Bitti.")

# %%
for i in range(10):
    if i == 3:
        continue # 3'ü yazdırmadan atla
    if i == 7:
        break    # 7'ye gelince döngüyü tamamen durdur
    print(i) # Çıktı: 0, 1, 2, 4, 5, 6
