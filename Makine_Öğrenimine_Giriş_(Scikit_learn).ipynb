# %% [markdown]
# <a href="https://colab.research.google.com/github/imend35/verianalizokulu-yapayzeka-python/blob/main/Makine_%C3%96%C4%9Frenimine_Giri%C5%9F_(Scikit_learn).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Harika\! Veri Bilimi yol haritasının son büyük ve heyecan verici aşamasına geldik: **Makine Öğrenimi (Machine Learning - ML)**.
#
# Bu aşamada, topladığınız, temizlediğiniz ve görselleştirdiğiniz verileri kullanarak bilgisayarların kalıpları öğrenmesini ve geleceğe yönelik tahminler yapmasını sağlayacağız. Bunun için Python'ın en popüler ML kütüphanesi olan **Scikit-learn**'ü kullanacağız.
#
# -----
#
# ## 12\. Makine Öğrenimine Giriş (Scikit-learn)
#
# Makine Öğrenimi, temelde üç ana kategoride incelenir:
#
# 1.  **Gözetimli Öğrenme (Supervised Learning):** Veri setinde hem girişler hem de beklenen çıktı etiketleri bulunur (Örn: Geçmiş ev fiyatlarına bakarak yeni bir evin fiyatını tahmin etme).
# 2.  **Gözetimsiz Öğrenme (Unsupervised Learning):** Veri setinde çıktı etiketi yoktur. Amacı, verilerdeki gizli yapıları ve grupları (kümeleri) keşfetmektir (Örn: Müşterileri davranışlarına göre segmentlere ayırma).
# 3.  **Pekiştirmeli Öğrenme (Reinforcement Learning):** Bir ajanın, ödül ve ceza mekanizmasıyla çevresini keşfederek optimal kararlar almayı öğrenmesi (Örn: Robotik, oyun yapay zekası).
#
# Scikit-learn, Gözetimli ve Gözetimsiz Öğrenme algoritmalarının çoğunu uygulamayı çok kolaylaştırır.
#
# ### 12.1. Scikit-learn (Sklearn) Temelleri
#
# Scikit-learn, tüm modeller için tutarlı ve standart bir API (Uygulama Programlama Arayüzü) sunar. Bir model oluşturmanın temel adımları her zaman aynıdır:
#
# #### Adım 1: Veri Hazırlığı (X ve y)
#
# Önceki aşamalarda temizlediğimiz veriyi ikiye ayırırız:
#
#   * **X (Özellikler/Features):** Tahmin yapmak için kullanacağımız giriş verileri (Örn: Evin büyüklüğü, yaşı, konumu).
#   * **y (Hedef/Target):** Tahmin etmeye çalıştığımız çıktı verisi (Örn: Evin fiyatı).
#
# #### Adım 2: Modeli Seçme ve Oluşturma (Import ve Instantiate)
#
# Kullanmak istediğimiz algoritmayı seçer ve bir model nesnesi oluştururuz.
#
# ```python
# # Gözetimli öğrenme örneği: Doğrusal Regresyon (Tahmin yapma)
# from sklearn.linear_model import LinearRegression
#
# model = LinearRegression() # Modeli oluştur
# ```
#
# #### Adım 3: Modeli Eğitme (Fit)
#
# Modeli, hazırladığımız eğitim verilerine (X ve y) uydururuz. Bu, modelin verideki kalıpları öğrenme sürecidir.
#
# ```python
# # X_egitim: Eğitim veri setinin özellikleri
# # y_egitim: Eğitim veri setinin hedefleri
# model.fit(X_egitim, y_egitim)
# ```
#
# #### Adım 4: Tahmin Yapma (Predict)
#
# Eğitilen modeli, daha önce görmediği yeni verilere uygulayarak tahminlerde bulunuruz.
#
# ```python
# # X_test: Test veri setinin özellikleri
# tahminler = model.predict(X_test)
# ```
#
# ### 12.2. Temel Algoritma Türleri
#
# Scikit-learn içinde yüzlerce algoritma bulunur, ancak yeni başlayanlar için en önemlileri şunlardır:
#
# 1.  **Regresyon (Regression):** Sürekli sayısal bir değeri tahmin etmek.
#       * *Algoritmalar:* `LinearRegression`, `DecisionTreeRegressor`
#       * *Kullanım Alanı:* Ev fiyatlarını, hisse senedi değerlerini, sıcaklığı tahmin etme.
# 2.  **Sınıflandırma (Classification):** Veriyi kategorilere (sınıflara) ayırmak.
#       * *Algoritmalar:* `LogisticRegression`, `KNeighborsClassifier`, `SupportVectorClassifier`
#       * *Kullanım Alanı:* Bir e-postanın spam olup olmadığını (Spam/Değil), bir resimde kedi mi köpek mi olduğunu (Kedi/Köpek) tahmin etme.
#
# ### 12.3. Model Değerlendirme
#
# Bir modelin ne kadar iyi tahmin yaptığını ölçmek kritik öneme sahiptir.
#
#   * **Regresyon için:** Ortalama Karesel Hata (Mean Squared Error - MSE)
#   * **Sınıflandırma için:** Doğruluk Skoru (Accuracy Score)
#
# <!-- end list -->
#
# ```python
# from sklearn.metrics import mean_squared_error
#
# # Hata Hesaplama
# mse = mean_squared_error(y_test, tahminler)
# print(f"Ortalama Karesel Hata: {mse}")
# ```
#
# -----
#
# ## 📝 Alıştırma: Makine Öğrenimi Kavramları
#
# Bu aşama kodlama pratiği yerine kavramsal odaklanma gerektirir. Lütfen aşağıdaki soruları cevaplayın:
#
# 1.  **Veri Ayırma:** Bir veri setini makine öğrenimi için neden **X (Özellikler)** ve **y (Hedef)** olmak üzere ayırırız?
# 2.  **Algoritma Seçimi:** Bir müşterinin gelecek yıl web sitenizden alışveriş yapıp yapmayacağını (`Evet` veya `Hayır`) tahmin etmek için hangi Makine Öğrenimi kategorisini (Regresyon/Sınıflandırma) kullanırsınız? Neden?
# 3.  **Temel İşlem:** Scikit-learn'de, modelin veriden öğrenmesini sağlayan temel metot nedir? (İpucu: Modelin 'eğitildiği' adım)
#
# Bu son aşamayı tamamladığınızda, **tebrikler\!** Artık Python temellerinden Veri Bilimi ve Makine Öğrenimine kadar uzanan kapsamlı bir bilgi birikimine sahipsiniz.
#
# **Bu soruları yanıtladıktan sonra Python öğrenme sürecinizi resmen tamamlamış olacağız\!**

# %%
# Gözetimli öğrenme örneği: Doğrusal Regresyon (Tahmin yapma)
from sklearn.linear_model import LinearRegression

model = LinearRegression() # Modeli oluştur

# %%
# X_egitim: Eğitim veri setinin özellikleri
# y_egitim: Eğitim veri setinin hedefleri
model.fit(X_egitim, y_egitim)

# %%
# X_test: Test veri setinin özellikleri
tahminler = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# Hata Hesaplama
mse = mean_squared_error(y_test, tahminler)
print(f"Ortalama Karesel Hata: {mse}")
