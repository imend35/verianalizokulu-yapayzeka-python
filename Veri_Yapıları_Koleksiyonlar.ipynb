# %% [markdown]
# <a href="https://colab.research.google.com/github/imend35/verianalizokulu-yapayzeka-python/blob/main/Veri_Yap%C4%B1lar%C4%B1_Koleksiyonlar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mükemmel ilerliyorsunuz\! Karar verme (if/else) ve tekrar etme (döngüler) yeteneklerini kazandınız. Şimdi programlamada birden fazla veriyi düzenli ve verimli bir şekilde tutmamızı sağlayan en önemli yapı taşlarına, yani **Python Veri Yapılarına (Koleksiyonlar)** geçiyoruz.
#
# Bu yapılar olmadan büyük verilerle çalışmak neredeyse imkansızdır.
#
# -----
#
# ## 5\. Veri Yapıları: Koleksiyonlar
#
# Python'da dört temel koleksiyon veri tipi vardır. Hepsi birden fazla değeri tek bir değişkende saklar, ancak farklı özelliklere sahiptirler:
#
# ### 5.1. Listeler (Lists)
#
# Python'daki en çok kullanılan ve en çok yönlü veri yapısıdır. Köşeli parantezler `[]` ile tanımlanır.
#
#   * **Sıralıdır (Ordered):** Elemanlar eklenme sırasına göre indexlenir (0'dan başlar).
#   * **Değiştirilebilirdir (Mutable):** Bir liste oluşturulduktan sonra elemanları değiştirilebilir, eklenebilir veya silinebilir.
#   * **İzin Verilen Tekrarlar:** Aynı değere sahip birden fazla eleman tutabilir.
#
# <!-- end list -->
#
# ```python
# # Tanımlama
# meyveler = ["elma", "muz", "çilek", "elma"]
#
# # Elemana Erişim (Indexleme)
# print(meyveler[1]) # Çıktı: muz (index 1)
#
# # Değer Değiştirme
# meyveler[2] = "kivi"
# print(meyveler) # Çıktı: ['elma', 'muz', 'kivi', 'elma']
#
# # Ekleme Metotları
# meyveler.append("portakal") # Listenin sonuna ekler
#
# # Silme Metodu
# meyveler.remove("elma") # İlk karşılaştığı 'elma'yı siler
# ```
#
# ### 5.2. Sözlükler (Dictionaries)
#
# Gerçek hayattaki bir sözlük gibi çalışır; **Anahtar (Key)** ve **Değer (Value)** çiftleri tutar. Anahtarlar, değerlere erişmek için kullanılır. Süslü parantezler `{}` ile tanımlanır.
#
#   * **Sırasızdı (Python 3.7+ sürümlerinde sıralı hale geldi, ancak ana mantığı anahtarla erişimdir).**
#   * **Değiştirilebilirdir (Mutable).**
#   * **Anahtarlar Tekil Olmalıdır:** Her anahtar benzersiz olmalıdır.
#
# <!-- end list -->
#
# ```python
# # Tanımlama
# kullanici = {
#     "ad": "Ece",
#     "yas": 28,
#     "sehir": "Ankara"
# }
#
# # Değere Erişim (Anahtarla)
# print(kullanici["yas"]) # Çıktı: 28
#
# # Yeni Eleman Ekleme/Değer Güncelleme
# kullanici["meslek"] = "Mühendis" # Yeni ekleme
# kullanici["yas"] = 29              # Var olanı güncelleme
# ```
#
# ### 5.3. Demetler (Tuples)
#
# Listelere benzerler ancak değiştirilemezler. Parantezler `()` ile tanımlanır.
#
#   * **Sıralıdır (Ordered).**
#   * **Değiştirilemezdir (Immutable):** Oluşturulduktan sonra eleman eklenemez, çıkarılamaz veya değiştirilemez.
#
# <!-- end list -->
#
# ```python
# koordinatlar = (10, 25)
#
# # Erişim aynıdır:
# print(koordinatlar[0]) # Çıktı: 10
#
# # Hata verir: koordinatlar[1] = 30 # 'tuple' object does not support item assignment
# ```
#
# ### 5.4. Kümeler (Sets)
#
# Matematikteki kümeler gibi çalışır; temel amacı **benzersiz elemanları** tutmaktır. Süslü parantezler `{}` ile tanımlanır (Sözlüklerden farkı Key-Value çifti olmamasıdır).
#
#   * **Sırasızdır (Unordered).**
#   * **Değiştirilebilirdir (Mutable).**
#   * **Tekrara İzin Vermez:** Otomatik olarak tekrar eden elemanları siler.
#
# <!-- end list -->
#
# ```python
# renkler = {"kırmızı", "mavi", "yeşil", "mavi"}
#
# print(renkler) # Çıktı: {'mavi', 'yeşil', 'kırmızı'} (Tekrar eden 'mavi' silindi ve sıra değişebilir)
#
# # Ekleme
# renkler.add("sarı")
# ```
#
# -----
#
# ## 📝 Alıştırma: Veri Yapılarını Kullanma
#
# 1.  **Liste Uygulaması:**
#       * `haftalik_harcamalar` adında bir liste oluşturun. Haftanın 5 günü için harcama miktarlarını (sayı olarak) ekleyin.
#       * Listenin sonuna `.append()` kullanarak yeni bir harcama ekleyin.
#       * Bir **For döngüsü** kullanarak listedeki tüm harcamaların toplamını hesaplayın ve ekrana yazdırın.
# 2.  **Sözlük Uygulaması:**
#       * `kitap` adında bir sözlük oluşturun. Anahtarlar: `"ad"`, `"yazar"`, `"sayfa_sayisi"`. Değerlerini atayın.
#       * Sözlüğe yeni bir anahtar/değer çifti ekleyin: `"basim_yili": 2022`.
#       * Yazarın adını ekrana yazdırın.
#
# Bu alıştırmaları tamamladığınızda, kodunuzu daha organize ve verimli hale getirecek olan **Fonksiyonlar ve Modüllere** geçmeye hazırız. **Hazır olduğunuzda lütfen bildirin.**

# %%
# Tanımlama
meyveler = ["elma", "muz", "çilek", "elma"]

# Elemana Erişim (Indexleme)
print(meyveler[1]) # Çıktı: muz (index 1)

# Değer Değiştirme
meyveler[2] = "kivi"
print(meyveler) # Çıktı: ['elma', 'muz', 'kivi', 'elma']

# Ekleme Metotları
meyveler.append("portakal") # Listenin sonuna ekler

# Silme Metodu
meyveler.remove("elma") # İlk karşılaştığı 'elma'yı siler

# %%
# Tanımlama
kullanici = {
    "ad": "Ece",
    "yas": 28,
    "sehir": "Ankara"
}

# Değere Erişim (Anahtarla)
print(kullanici["yas"]) # Çıktı: 28

# Yeni Eleman Ekleme/Değer Güncelleme
kullanici["meslek"] = "Mühendis" # Yeni ekleme
kullanici["yas"] = 29              # Var olanı güncelleme

# %%
koordinatlar = (10, 25)

# Erişim aynıdır:
print(koordinatlar[0]) # Çıktı: 10

# Hata verir: koordinatlar[1] = 30 # 'tuple' object does not support item assignment

# %%
renkler = {"kırmızı", "mavi", "yeşil", "mavi"}

print(renkler) # Çıktı: {'mavi', 'yeşil', 'kırmızı'} (Tekrar eden 'mavi' silindi ve sıra değişebilir)

# Ekleme
renkler.add("sarı")
