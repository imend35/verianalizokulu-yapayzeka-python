# %% [markdown]
# <a href="https://colab.research.google.com/github/imend35/verianalizokulu-yapayzeka-python/blob/main/Veri_G%C3%B6rselle%C5%9Ftirme_(Matplotlib_%26_Seaborn).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mükemmel\! Pandas ile veri manipülasyonunun temellerini öğrendiniz. Şimdi, Veri Bilimi döngüsünün en önemli adımlarından birine, yani **Veri Görselleştirmeye** geçiyoruz.
#
# Veri setindeki eğilimleri, anormallikleri ve ilişkileri sadece sayılara bakarak anlamak zordur. Grafik ve çizelgeler, bu bilgileri bir bakışta anlaşılır hale getirir. Bu aşamada, iki ana Python kütüphanesini kullanacağız: **Matplotlib** ve **Seaborn**.
#
# -----
#
# ## 11\. Veri Görselleştirme (Matplotlib & Seaborn)
#
# ### 11.1. Matplotlib: Temel Çizim Kütüphanesi
#
# Matplotlib, Python'da grafik çiziminin temelini oluşturur. Diğer kütüphaneler bile genellikle onun üzerine inşa edilmiştir. Standart olarak `plt` takma adıyla kullanılır.
#
# #### 💡 Kütüphaneyi İçe Aktarma
#
# ```python
# import matplotlib.pyplot as plt
# import pandas as pd # Önceki DataFrame'i kullanacağımız için
# ```
#
# #### Temel Grafik Türleri
#
# Matplotlib ile en yaygın kullanılan grafik türleri şunlardır:
#
# 1.  **Çizgi Grafiği (`plt.plot()`):** Zaman içindeki değişimleri veya sürekli verileri göstermek için kullanılır.
# 2.  **Dağılım Grafiği (Scatter Plot - `plt.scatter()`):** İki değişken arasındaki ilişkiyi göstermek için kullanılır.
# 3.  **Histogram (`plt.hist()`):** Bir değişkenin değer dağılımını (hangi değer aralığında ne kadar veri olduğunu) göstermek için kullanılır.
#
# <!-- end list -->
#
# ```python
# # Örnek Veri
# veri = pd.DataFrame({
#     'Yıl': [2018, 2019, 2020, 2021, 2022],
#     'Satış': [150, 200, 180, 250, 300]
# })
#
# plt.figure(figsize=(8, 4)) # Grafiğin boyutunu ayarlar
#
# # Çizgi Grafiği Oluşturma
# plt.plot(veri['Yıl'], veri['Satış'], marker='o', color='blue')
#
# # Grafik Başlıkları ve Etiketleri
# plt.title('Yıllara Göre Satış Performansı')
# plt.xlabel('Yıl')
# plt.ylabel('Toplam Satış (Bin)')
# plt.grid(True) # Izgara çizgilerini ekler
#
# plt.show() # Grafiği gösterir
# ```
#
# ### 11.2. Seaborn: İstatistiksel Görselleştirme
#
# Seaborn, Matplotlib üzerine kurulmuş ve istatistiksel grafikler oluşturmayı kolaylaştıran, daha çekici ve bilgilendirici görseller sunan bir kütüphanedir. Standart olarak `sns` takma adıyla kullanılır.
#
# #### 💡 Kütüphaneyi İçe Aktarma
#
# ```python
# import seaborn as sns
# ```
#
# #### Seaborn Avantajları ve Türleri
#
# Seaborn, Pandas DataFrameleri ile doğrudan çalışmak üzere optimize edilmiştir.
#
# 1.  **Dağılım Grafiği (Scatter Plot - `sns.scatterplot()`):** Matplotlib'den farklı olarak, üçüncü bir değişkeni renkle (`hue` parametresi) kolayca gösterebilir.
# 2.  **Kutu Grafiği (Box Plot - `sns.boxplot()`):** Bir değişkenin dağılımını, medyanını ve aykırı değerlerini (outliers) göstermek için harikadır.
# 3.  **Isı Haritası (Heatmap - `sns.heatmap()`):** İki boyutlu verilerin yoğunluğunu veya değişkenler arasındaki korelasyonu renklerle gösterir.
#
# <!-- end list -->
#
# ```python
# # Örnek Veri (Önceki df'i kullanalım)
# # df, Yaş ve Puan sütunlarını içeriyordu
#
# plt.figure(figsize=(6, 5))
#
# # Kutu Grafiği Örneği (Puan dağılımını gösterir)
# sns.boxplot(y=df['Puan'])
# plt.title('Puan Dağılımı (Box Plot)')
# plt.show()
#
# # İki Değişken Arası İlişki (Dağılım Grafiği)
# # sns.scatterplot(x=df['Yaş'], y=df['Puan'])
# # plt.title('Yaş ve Puan İlişkisi')
# # plt.show()
# ```
#
# -----
#
# ## 📝 Alıştırma: Veriyi Görselleştirme
#
# Bu alıştırma için, önceki Pandas alıştırmasında oluşturduğunuz `df` DataFrame'ini (İsim, Yaş, Puan, Mezuniyet\_Yili) kullanın:
#
# 1.  **Histogram Çizme (Matplotlib):**
#       * `plt.hist()` metodunu kullanarak `df['Puan']` sütunundaki verilerin dağılımını gösteren bir histogram çizin.
#       * Grafiğe bir başlık (`plt.title`) eklemeyi unutmayın.
# 2.  **Kutu Grafiği (Seaborn):**
#       * `sns.boxplot()` metodunu kullanarak **`Yaş`** sütununun dağılımını gösteren bir kutu grafiği çizin.
#
# Bu aşamayı tamamladıktan sonra, veri bilimindeki son büyük adıma, yani **Makine Öğrenimi (Scikit-learn)** kütüphanesine geçmeye hazır olacaksınız. **Hazır olduğunuzda lütfen bildirin\!**

# %%
import matplotlib.pyplot as plt
import pandas as pd # Önceki DataFrame'i kullanacağımız için
veri = pd.DataFrame({
    'Yıl': [2018, 2019, 2020, 2021, 2022],
    'Satış': [150, 200, 180, 250, 300]
})

plt.figure(figsize=(8, 4)) # Grafiğin boyutunu ayarlar

# Çizgi Grafiği Oluşturma
plt.plot(veri['Yıl'], veri['Satış'], marker='o', color='blue')

# Grafik Başlıkları ve Etiketleri
plt.title('Yıllara Göre Satış Performansı')
plt.xlabel('Yıl')
plt.ylabel('Toplam Satış (Bin)')
plt.grid(True) # Izgara çizgilerini ekler

plt.show() # Grafiği gösterir

# %%
import matplotlib.pyplot as plt
import pandas as pd # Önceki DataFrame'i kullanacağımız için
# Örnek Veri (Önceki df'i kullanalım)
# df, Yaş ve Puan sütunlarını içeriyordu

plt.figure(figsize=(6, 5))

# Kutu Grafiği Örneği (Puan dağılımını gösterir)
sns.boxplot(y=df['Puan'])
plt.title('Puan Dağılımı (Box Plot)')
plt.show()

# İki Değişken Arası İlişki (Dağılım Grafiği)
# sns.scatterplot(x=df['Yaş'], y=df['Puan'])
# plt.title('Yaş ve Puan İlişkisi')
# plt.show()
