# %% [markdown]
# <a href="https://colab.research.google.com/github/imend35/verianalizokulu-yapayzeka-python/blob/main/Operat%C3%B6rler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Harika\! Temel yapı taşlarını sağlamca attık. Şimdi, bu değişkenler ve değerler üzerinde işlemler yapmamızı sağlayan **Operatörler** konusuna geçiyoruz.
#
# Operatörler, Python'da değişkenleri, değerleri ve ifadeleri manipüle etmek için kullanılan özel sembollerdir.
#
# -----
#
# ## 3\. Operatörler: İşlem Yapma Gücü 💪
#
# Python'da en çok kullanılan dört ana operatör grubu şunlardır:
#
# ### 3.1. Aritmetik Operatörler
#
# Matematiksel işlemleri yapmak için kullanılırlar.
#
# | Operatör | Tanım | Örnek | Sonuç |
# | :---: | :--- | :---: | :---: |
# | `+` | Toplama | `5 + 3` | `8` |
# | `-` | Çıkarma | `10 - 4` | `6` |
# | `*` | Çarpma | `6 * 2` | `12` |
# | `/` | Bölme (Float) | `10 / 3` | `3.333...` |
# | `//` | Tam Bölme (Integer) | `10 // 3` | `3` |
# | `%` | Modül (Kalan) | `10 % 3` | `1` |
# | `**` | Üs Alma | `2 ** 3` | `8` |
#
# > **Önemli:** Bölme operatörü (`/`) her zaman ondalıklı (float) bir sonuç döndürür. Tam sayı bir sonuç istiyorsanız `//` kullanın.
#
# ### 3.2. Karşılaştırma Operatörleri
#
# İki değeri karşılaştırır ve sonuç olarak her zaman bir **Boolean** (`True` veya `False`) değeri döndürür.
#
# | Operatör | Tanım | Örnek | Sonuç |
# | :---: | :--- | :---: | :---: |
# | `==` | Eşittir | `5 == 5` | `True` |
# | `!=` | Eşit Değildir | `5 != 3` | `True` |
# | `>` | Büyüktür | `8 > 6` | `True` |
# | `<` | Küçüktür | `8 < 6` | `False` |
# | `>=` | Büyük Eşittir | `5 >= 5` | `True` |
# | `<=` | Küçük Eşittir | `7 <= 5` | `False` |
#
# ### 3.3. Atama Operatörleri
#
# Değişkenlere değer atamak için kullanılırlar. `=` en temel atama operatörüdür.
#
# | Operatör | Örnek | Eşdeğeri | Açıklama |
# | :---: | :---: | :---: | :--- |
# | `=` | `x = 5` | - | `x`'e `5` değerini atar. |
# | `+=` | `x += 3` | `x = x + 3` | `x`'in değerini `3` artırır. |
# | `-=` | `x -= 2` | `x = x - 2` | `x`'in değerini `2` azaltır. |
# | `*=` | `x *= 4` | `x = x * 4` | `x`'i `4` ile çarpar. |
# | `/=` | `x /= 2` | `x = x / 2` | `x`'i `2`'ye böler. |
#
# ```python
# # Atama Operatörleri Örneği
# sayi = 10
# sayi += 5   # sayi = 10 + 5, yani şimdi sayi = 15
# print(sayi) # Çıktı: 15
# ```
#
# ### 3.4. Mantıksal Operatörler
#
# Boolean (mantıksal) değerler üzerinde işlem yapar ve yine Boolean sonuç döndürürler. Bu operatörler, **Kontrol Akışı** konusunda (bir sonraki konumuz) kritik öneme sahiptir.
#
# 1.  **`and` (VE):** Her iki ifade de `True` ise `True` döndürür. Aksi takdirde `False`.
# 2.  **`or` (VEYA):** İfadelerden herhangi biri `True` ise `True` döndürür. Yalnızca her ikisi de `False` ise `False`.
# 3.  **`not` (DEĞİL):** İfadenin tam tersini döndürür.
#
# <!-- end list -->
#
# ```python
# # Mantıksal Operatörler Örnekleri
# yas = 20
# ehliyet_var = True
#
# # 1. and (VE)
# yetkili = (yas >= 18) and ehliyet_var
# print(yetkili) # Çıktı: True (Çünkü 20 >= 18 True VE ehliyet_var True)
#
# # 2. not (DEĞİL)
# ehliyetsiz = not ehliyet_var
# print(ehliyetsiz) # Çıktı: False
# ```
#
# -----
#
# ## 📝 Alıştırma: Operatörleri Kullanma
#
# 1.  `başlangıç_değeri` adında bir değişken oluşturun ve `5` değerini atayın.
# 2.  `+=` atama operatörünü kullanarak bu değere `3` ekleyin.
# 3.  `çarpım` adında bir değişken tanımlayın ve `başlangıç_değeri`ni `2` ile çarpın.
# 4.  Aşağıdaki mantıksal ifadeyi değerlendirin ve sonucu `sonuc` değişkenine atayın:
#       * **Koşul:** `(başlangıç_değeri 8'e eşit mi?) VEYA (çarpım 15'ten büyük mü?)`
# 5.  `başlangıç_değeri`, `çarpım` ve `sonuc` değişkenlerinin değerlerini ekrana yazdırın.
#
# **Bu görevleri tamamladığınızda, programlamanın en temel ve en önemli konusu olan Kontrol Akışına (If-Else ve Döngüler) geçmeye hazır olacaksınız.**

# %%
# Atama Operatörleri Örneği
sayi = 10
sayi += 5   # sayi = 10 + 5, yani şimdi sayi = 15
print(sayi) # Çıktı: 15
# Out:
# 15

# %%
# Mantıksal Operatörler Örnekleri
yas = 20
ehliyet_var = True

# 1. and (VE)
yetkili = (yas >= 18) and ehliyet_var
print(yetkili) # Çıktı: True (Çünkü 20 >= 18 True VE ehliyet_var True)

# 2. not (DEĞİL)
ehliyetsiz = not ehliyet_var
print(ehliyetsiz) # Çıktı: False
# Out:
# True
# False
