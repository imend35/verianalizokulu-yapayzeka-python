# %% [markdown]
# <a href="https://colab.research.google.com/github/imend35/verianalizokulu-yapayzeka-python/blob/main/De%C4%9Fi%C5%9Fkenler_ve_Veri_Tipleri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Harika\! Python yolculuğunuza **Değişkenler (Variables)** ve **Veri Tipleri (Data Types)** ile başlayalım. Bu iki kavram, her programlama dilinin yapı taşıdır.
#
# -----
#
# ## 1\. Değişkenler: Programlamanın Saklama Kutuları 📦
#
# Değişkenler, verileri (sayılar, metinler vb.) geçici olarak hafızada tutmak için kullanılan etiketlerdir. Python'da bir değişken oluşturmak çok basittir: sadece bir ad verin ve değer atayın.
#
# ### Tanımlama Kuralları:
#
# 1.  **Başlangıç:** Değişken adı bir harfle veya alt çizgi (\_) ile başlamalıdır. Rakamla **başlayamaz**.
# 2.  **İçerik:** Değişken adı sadece alfanümerik karakterler (A-z, 0-9) ve alt çizgi içerebilir.
# 3.  **Büyük/Küçük Harf:** Python büyük/küçük harfe duyarlıdır. `yas` ile `Yas` iki farklı değişkendir.
# 4.  **Ayrılmış Kelimeler:** `if`, `for`, `while` gibi Python'ın kendine ait komutlarını (anahtar kelimeleri) kullanamazsınız.
#
# ### Örnek Atama:
#
# ```python
# isim = "Ayşe"     # String (Metin)
# sayi_bir = 10     # Integer (Tam Sayı)
# ortalama = 95.5   # Float (Ondalıklı Sayı)
# aktif = True      # Boolean (Mantıksal Değer)
#
# # Değişkenlere değer atamak için = (eşittir) operatörü kullanılır.
# ```
#
# -----
#
# ## 2\. Veri Tipleri: Hangi Bilgiyi Saklıyoruz?
#
# Python'da sakladığınız her değerin bir tipi vardır. Python, değişkenin tipini otomatik olarak anlar.
#
# ### Temel Veri Tipleri:
#
# #### 🟢 Sayısal Tipler (Numeric Types)
#
# Sayıları temsil ederler.
#
# 1.  **Integer (`int`): Tam Sayılar**
#       * Negatif ve pozitif bütün tam sayılar.
#       * *Örnek:* `yas = 30`, `kredi_puanı = 750`
# 2.  **Float (`float`): Ondalıklı Sayılar**
#       * Ondalık ayıracı olarak nokta (`.`) kullanılır.
#       * *Örnek:* `pi = 3.14159`, `fiyat = 49.99`
#
# #### 🔵 Metin Tipi (Text Type)
#
# 1.  **String (`str`): Metinler**
#       * Tek tırnak (`'`) veya çift tırnak (`"`) arasına yazılan her şey metin (String) olarak kabul edilir.
#       * *Örnek:* `selam = "Merhaba Dünya"`, `harf = 'A'`
#
# #### 🟣 Mantıksal Tip (Boolean Type)
#
# 1.  **Boolean (`bool`): Mantıksal Değerler**
#       * Sadece iki olası değeri vardır: **`True`** (Doğru) veya **`False`** (Yanlış).
#       * Genellikle koşul durumlarında (ifadesi doğru mu, yanlış mı?) kullanılır.
#       * *Örnek:* `hava_yagmurlu = False`, `kullanici_giris_yapti = True`
#
# ### 💡 Veri Tipini Öğrenme:
#
# Bir değişkenin tipini öğrenmek için **`type()`** fonksiyonunu kullanabilirsiniz:
#
# ```python
# kullanici_adi = "Ali"
# print(type(kullanici_adi))  # Çıktı: <class 'str'>
#
# sayac = 5
# print(type(sayac))          # Çıktı: <class 'int'>
# ```
#
# ### Önemli Not: Tip Dönüşümü (Type Casting)
#
# Bazen bir veri tipini başka bir tipe dönüştürmeniz gerekebilir.
#
#   * `int()`: Bir değeri tam sayıya dönüştürür.
#   * `float()`: Bir değeri ondalıklı sayıya dönüştürür.
#   * `str()`: Bir değeri metne dönüştürür.
#
# <!-- end list -->
#
# ```python
# sayi_metin = "150"
# sayi_int = int(sayi_metin) # "150" stringi, 150 tam sayısına dönüştü
#
# oran = 0.5
# oran_metin = str(oran)     # 0.5 float'ı, "0.5" stringine dönüştü
# ```
#
# -----
#
# ## 📝 Alıştırma Zamanı
#
# Şimdi öğrendiklerinizi uygulayabileceğiniz basit bir görev:
#
# 1.  Adınız için bir **String** değişkeni oluşturun.
# 2.  Yaşınız için bir **Integer** değişkeni oluşturun.
# 3.  Boyunuz için (metre cinsinden, ondalıklı) bir **Float** değişkeni oluşturun.
# 4.  Bu üç değişkeni de `print()` komutuyla ekrana yazdırın.
# 5.  Son olarak, `type()` fonksiyonunu kullanarak **yaş** değişkeninizin tipini kontrol edin ve çıktıyı yazın.
#
# **Örnek çıktınız şöyle olmalı:**
#
# ```
# Adım: [Sizin Adınız]
# Yaşım: [Sizin Yaşınız]
# Boyum: [Sizin Boyunuz]
# <class 'int'>
# ```

# %%
isim = "Ayşe"     # String (Metin)
sayi_bir = 10     # Integer (Tam Sayı)
ortalama = 95.5   # Float (Ondalıklı Sayı)
aktif = True      # Boolean (Mantıksal Değer)

# Değişkenlere değer atamak için = (eşittir) operatörü kullanılır.

# %%
kullanici_adi = "Ali"
print(type(kullanici_adi)) # Çıktı: <class 'str'>

sayac=5
print(type(sayac))# Çıktı: <class 'int'>
# Out:
# <class 'str'>
# <class 'int'>

# %%
sayi_metin = "150"
sayi_int = int(sayi_metin) # "150" stringi, 150 tam sayısına dönüştü

oran = 0.5
oran_metin = str(oran)     # 0.5 float'ı, "0.5" stringine dönüştü
