# %% [markdown]
# <a href="https://colab.research.google.com/github/imend35/verianalizokulu-yapayzeka-python/blob/main/Veri_Bilimi_ve_Analizi_%C4%B0leri_Yol_Haritas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Elbette, o zaman en çok ilgi çeken alanlardan biri olan **Veri Bilimi ve Analizi** yolunda ilerleyelim. Bu alan, Python'ın gücünü en çok gösterdiği yerdir.
#
# Bu aşama, temel Python bilgilerinizi gerçek dünya verileri üzerinde kullanmaya başlamanızı sağlayacak bir köprü kurar.
#
# ---
#
# ## Veri Bilimi ve Analizi: İleri Yol Haritası
#
# Bu yol haritası, sizi temel Python bilgisine sahip birinden, veri setlerini analiz edebilen, temizleyebilen ve görselleştirebilen birine dönüştürecektir.
#
# ### Aşama 1: Sayısal Hesaplamaların Temeli (NumPy)
#
# | Konu Başlığı | Odak Noktası | Detaylı Açıklama |
# | :--- | :--- | :--- |
# | **NumPy Dizileri (Arrays)** | `np.array()` | Listenin aksine, tek bir veri tipi (genellikle sayı) tutan, çok daha hızlı çalışan N-boyutlu diziler oluşturma. |
# | **Dizi İşlemleri** | Indexleme, dilimleme, şekillendirme. | Büyük veri setlerine hızlı erişim. `.reshape()` ile dizinin boyutlarını değiştirme. |
# | **Vektörizasyon** | Hızlı matematiksel işlemler. | Döngüler kullanmak yerine, tüm dizilere aynı anda işlem uygulayarak performansı artırma. |
#
# ### Aşama 2: Veri Analizinin Bel Kemiği (Pandas)
#
# Pandas, veri biliminde en çok kullanılan kütüphanedir. Veriyi tablo formatında, yani **DataFrame** olarak tutar.
#
# | Konu Başlığı | Odak Noktası | Detaylı Açıklama |
# | :--- | :--- | :--- |
# | **DataFrame Oluşturma** | Tablo yapısının temelleri. | Verileri sözlükler veya listelerden DataFrame'e dönüştürme. (Veri Biliminde Excel tablosuna karşılık gelir.) |
# | **Veri Yükleme/Kaydetme** | `pd.read_csv()`, `.to_csv()` | Veri setlerini (CSV, JSON, Excel vb.) hızlıca okuma ve analiz sonrası kaydetme. |
# | **Veri Temizliği (Data Cleaning)** | Eksik değerler, tekrar eden satırlar. | `NaN` (Not a Number) olarak gelen eksik verileri tespit etme, doldurma (`.fillna()`) veya silme (`.dropna()`). |
# | **Veri Manipülasyonu** | Filtreleme, Sıralama, Gruplama. | Belirli koşulları sağlayan satırları seçme, veriyi belirli bir sütuna göre sıralama (`.sort_values()`) ve `groupby()` ile özet çıkarma. |
#
#
#
# ### Aşama 3: Veri Görselleştirme (Matplotlib & Seaborn)
#
# Verideki eğilimleri, desenleri ve anormallikleri hızla anlamak için görselleştirme şarttır.
#
# | Kütüphane | Görselleştirme Türü | Amacı |
# | :--- | :--- | :--- |
# | **Matplotlib** | Çizgi Grafikleri, Saçılım Grafikleri, Histogramlar. | Temel ve özelleştirilebilir grafikler oluşturur. Pandas çıktılarını görselleştirmede kullanılır. |
# | **Seaborn** | Isı Haritaları, Kutu Grafikleri (Box Plots). | Daha estetik ve istatistiksel açıdan zengin görseller oluşturur. İki veya daha fazla değişken arasındaki ilişkileri göstermede etkilidir. |
#
# ---
#
# ## 📝 Uygulama Önerisi: Gerçek Bir Proje
#
# Bu konuları öğrenirken, küçük parçalar halinde ilerlemek yerine büyük bir amaca odaklanın:
#
# > **Halka Açık Bir Veri Seti Analizi (Örn: Titanic veya Iris Veri Seti):**
# >
# > 1.  Pandas ile veriyi yükleyin.
# > 2.  Eksik değerleri (yaş, kamaralar vb.) tespit edin ve doldurun.
# > 3.  **Matplotlib** kullanarak yolcuların yaş dağılımını (Histogram) görselleştirin.
# > 4.  **Pandas `groupby()`** metodunu kullanarak cinsiyete ve bilet sınıfına göre hayatta kalma oranlarını hesaplayın.
# > 5.  Bu analiz sonuçlarını özetleyen metinler hazırlayın.
#
# **Bu yol haritası sizi heyecanlandırdı mı? NumPy ile başlamak için hazırsanız, ilk konuya, yani NumPy dizilerine geçelim!**
