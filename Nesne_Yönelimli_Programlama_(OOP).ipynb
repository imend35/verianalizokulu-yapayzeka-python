# %% [markdown]
# <a href="https://colab.research.google.com/github/imend35/verianalizokulu-yapayzeka-python/blob/main/Nesne_Y%C3%B6nelimli_Programlama_(OOP).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Harika\! Son temel konuya gelmiş bulunuyoruz: **Nesne Yönelimli Programlama (Object-Oriented Programming - OOP)**.
#
# OOP, modern yazılım geliştirmenin temelini oluşturur ve büyük, karmaşık sistemleri yönetmenin en etkili yoludur. Bu yaklaşım, gerçek dünyadaki nesneleri kod dünyasına taşıyarak programlamayı daha sezgisel ve modüler hale getirir.
#
# -----
#
# ## 8\. Nesne Yönelimli Programlama (OOP)
#
# ### 8.1. Sınıflar (Classes) ve Nesneler (Objects)
#
# OOP'nin kalbinde bu iki kavram yer alır:
#
#   * **Sınıf (Class):** Nesnelerin şablonu, planı veya kalıbıdır. Bir sınıf, nesnenin sahip olabileceği **özellikleri (Attributes)** ve yapabileceği **davranışları (Methods - Fonksiyonları)** tanımlar.
#       * *Örnek:* Bir **Araba** sınıfı.
#   * **Nesne (Object):** Sınıfın somut bir örneğidir. Şablondan üretilmiş, kendine has değerlere sahip olan gerçek varlıktır.
#       * *Örnek:* Kırmızı renkli, 2020 model bir **Araba** (nesne).
#
# #### Sınıf Tanımlama
#
# Sınıflar `class` anahtar kelimesi ile tanımlanır.
#
# ```python
# class Araba:
#     # 1. Özellikler (Attributes)
#     marka = "Bilinmiyor"
#
#     # 2. Kurucu Metot (__init__)
#     # Bir nesne yaratıldığında otomatik çalışan metottur.
#     # self: Oluşturulan nesnenin kendisini temsil eder. Zorunludur.
#     def __init__(self, renk, model_yili):
#         self.renk = renk          # Nesneye özgü bir özellik
#         self.model_yili = model_yili # Nesneye özgü bir özellik
#
#     # 3. Davranışlar/Metotlar (Methods)
#     def calistir(self):
#         print(f"{self.renk} {self.marka} çalıştırıldı.")
#
# # Nesne (Object) Oluşturma (Sınıfın somut örneğini türetme)
# araba1 = Araba("Mavi", 2022) # Yeni bir Araba nesnesi oluşturuldu
# araba2 = Araba("Kırmızı", 2018)
#
# # Özelliklere Erişim
# print(f"Araba 1'in rengi: {araba1.renk}") # Çıktı: Mavi
#
# # Metodu Çağırma
# araba1.calistir() # Çıktı: Mavi Bilinmiyor çalıştırıldı.
# ```
#
# ### 8.2. OOP'nin Dört Temel İlkesi
#
# 1.  **Kapsülleme (Encapsulation):** Verileri (özellikleri) ve o veriler üzerinde çalışan metotları bir araya getirerek tek bir birim (sınıf) içinde tutmaktır. Bu, verilerin dışarıdan yanlışlıkla değiştirilmesini önler.
#
# 2.  **Miras/Kalıtım (Inheritance):** Bir sınıfın (Alt Sınıf/Çocuk Sınıf) başka bir sınıfın (Üst Sınıf/Ebeveyn Sınıf) tüm özelliklerini ve metotlarını devralmasıdır. Kod tekrarını önler.
#
#     ```python
#     class Hayvan:
#         def ses_cikar(self):
#             pass # Fonksiyonun içini boş bırakır
#
#     class Kopek(Hayvan): # Kopek, Hayvan sınıfından miras alır
#         def ses_cikar(self):
#             print("Hav hav!")
#
#     kopek1 = Kopek()
#     kopek1.ses_cikar() # Çıktı: Hav hav!
#     ```
#
# 3.  **Çok Biçimlilik (Polymorphism):** Farklı nesnelerin aynı metoda farklı şekillerde cevap verebilmesidir. Yukarıdaki örnekte, hem `Kopek` hem de bir `Kedi` sınıfı `ses_cikar()` metoduna sahip olabilir, ancak her biri kendi özel sesini çıkarır.
#
# 4.  **Soyutlama (Abstraction):** Kullanıcıya sadece gerekli olan bilgileri göstermek ve karmaşık arka plan detaylarını gizlemektir (Kullanıcının motorun nasıl çalıştığını bilmesine gerek kalmadan arabayı sürmesi gibi).
#
# -----
#
# ## 📝 Alıştırma: Nesne Yönelimli Programlama
#
# 1.  **Sınıf Tanımlama:**
#       * `Ogrenci` adında bir sınıf oluşturun.
#       * Bu sınıfın bir `__init__` metodu olsun. Bu metot, bir öğrencinin `ad` ve `ogrenci_no` değerlerini alsın ve bu değerleri nesne özelliklerine atayın.
#       * Sınıfa `bilgileri_goster` adında bir metot ekleyin. Bu metot, öğrencinin adını ve numarasını ekrana yazdırsın.
# 2.  **Nesne Oluşturma:**
#       * Bu sınıftan `ogrenci_a` ve `ogrenci_b` adında iki farklı nesne türetin (örnekleyin).
#       * Her iki nesne için de `bilgileri_goster` metodunu çağırın.
#
# Bu son temel adımı da başarıyla tamamladınız\! **Python Temellerini** bitirdiniz.
#
# ### 🌟 Sonraki Adımlarınız İçin Öneriler
#
#   * **Pratik Yapın:** Bu öğrendiğiniz tüm konuları birleştirerek küçük projeler yapın (Basit bir banka uygulaması, yapılacaklar listesi uygulaması vb.).
#   * **Kütüphaneler:** Artık Python'ı belirli alanlarda uzmanlaşmak için kullanabilirsiniz:
#       * **Web Geliştirme:** Flask/Django
#       * **Veri Bilimi:** Pandas, NumPy
#       * **Makine Öğrenimi/Yapay Zeka:** Scikit-learn, TensorFlow
#
# **İsterseniz bu yol haritasında bahsettiğimiz temel konuları bir kez daha özetleyebilir veya Python'da ileride kullanabileceğiniz popüler kütüphanelere genel bir bakış atabiliriz.**

# %%
class Araba:
    # 1. Özellikler (Attributes)
    marka = "Bilinmiyor"

    # 2. Kurucu Metot (__init__)
    # Bir nesne yaratıldığında otomatik çalışan metottur.
    # self: Oluşturulan nesnenin kendisini temsil eder. Zorunludur.
    def __init__(self, renk, model_yili):
        self.renk = renk          # Nesneye özgü bir özellik
        self.model_yili = model_yili # Nesneye özgü bir özellik

    # 3. Davranışlar/Metotlar (Methods)
    def calistir(self):
        print(f"{self.renk} {self.marka} çalıştırıldı.")

# Nesne (Object) Oluşturma (Sınıfın somut örneğini türetme)
araba1 = Araba("Mavi", 2022) # Yeni bir Araba nesnesi oluşturuldu
araba2 = Araba("Kırmızı", 2018)

# Özelliklere Erişim
print(f"Araba 1'in rengi: {araba1.renk}") # Çıktı: Mavi

# Metodu Çağırma
araba1.calistir() # Çıktı: Mavi Bilinmiyor çalıştırıldı.

# %%
class Hayvan:
    def ses_cikar(self):
        pass # Fonksiyonun içini boş bırakır

class Kopek(Hayvan): # Kopek, Hayvan sınıfından miras alır
    def ses_cikar(self):
        print("Hav hav!")

kopek1 = Kopek()
kopek1.ses_cikar() # Çıktı: Hav hav!
